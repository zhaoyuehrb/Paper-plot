# %%
import pandas as pd
import matplotlib as mpl
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
fid = pd.read_csv('../../RBC_fid_table.csv')
fid.head(2)
# Out:
#   Barcodes  Sets Types  Timepoint Position      FileName
# 0   ATCACG     8   S24          0   ATCACG  ATCACG-s_5_1
# 1   TTAGGC     8   S24          1   TTAGGC  TTAGGC-s_5_1

# %%
fileset = 'ATCACG-s_5_1'
filename= 'gene_TXCDUTR_ReadOutput_processedData_24filesDec_ACAGTG-s_5_1_shift15.txt'

# %%
txcdutr = pd.read_csv('txcdutr/'+filename,sep='\t')
del txcdutr['AccNum']
del txcdutr['ExonReads']
del txcdutr['RefseqReads']
del txcdutr['GenomeRefseqReads']
txcdutr.head(3)
# Out:
#    IntronReads  CD_GenomeRefseqReads  fpUTR_reads  tpUTR_reads
# 0          8.0                 144.0          2.0         11.0
# 1          0.0                   6.0          0.0          5.0
# 2          0.0                 471.0         36.0          3.0

# %%
df = txcdutr.stack().reset_index()
df.columns = ['x', 'hue', 'y']
df
# Out:
#            x                   hue       y
# 0          0           IntronReads     8.0
# 1          0  CD_GenomeRefseqReads   144.0
# 2          0           fpUTR_reads     2.0
# 3          0           tpUTR_reads    11.0
# 4          1           IntronReads     0.0
# ...      ...                   ...     ...
# 76835  19208           tpUTR_reads     5.0
# 76836  19209           IntronReads     2.0
# 76837  19209  CD_GenomeRefseqReads  2512.0
# 76838  19209           fpUTR_reads   782.0
# 76839  19209           tpUTR_reads    14.0
#
# [76840 rows x 3 columns]

# %%
ax=sns.violinplot(x='hue',y='y',#hue='hue',
           data=df)
ax.set_xticklabels(['Intron','CDS','fpUTR','tpUTR'])
fig = ax.get_figure()
fig.savefig('sample.eps')
