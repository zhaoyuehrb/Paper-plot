# %%
import pandas as pd

# %%
res=pd.read_csv('te_cluster_kcosine.gct',sep='\t')
res = res.sort_values(by='k_means_8')

# %%
for i in range(1,9):
    cur=res.loc[res['k_means_8']==i,'id'].values
    with open('cluster '+str(i)+' genes.txt', 'a') as f:
        for c in cur:
            f.write(c+'\n')

# %%
# !touch command.txt

# %%
for i in range(1,9):
    with open('command.txt','a') as f:
        f.write('python2 ChartReport.py background.txt cluster\ '+str(i)+'\ genes.txt GO_cluster'+str(i)+'.txt\n')
